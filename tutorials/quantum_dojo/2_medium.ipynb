# %% [markdown]
# # Quantum Dojo - Medium
#
# Starting from a quantum state $|\psi⟩$ (represented by a diagram of its statevector), your goal is to:
# 1. Find the quantum circuit that produces this specific state,
# 2. Visualize the statevector using `plot_statevector(state)`.
#
# To find the quantum circuit, you can use:
# - [IBM Quantum Composer](https://quantum.ibm.com/composer/) (use only to help you design the solution), OR
# - Source code (Jupyter notebook)
#
# At the end, provide your solutions in this notebook for each kata as source code.

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# statevector visualization
from statevector_visualizer import plot_statevector

# %% [markdown]
# # Kata 1:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_1.png" alt="kata_1" width="900"/>  |  <img src="images/kata_1_code.png" alt="kata_1_code" width="900"/>

# %%
def kata_1():
    circuit = QuantumCircuit(3)
    
    # todo: complete the circuit

    return circuit

# %%
qc = kata_1()
qc.draw('mpl', style="clifford")

# %%
plot_statevector(qc)

# %% [markdown]
# # Kata 2:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_2.png" alt="kata_2" width="900"/>  |  <img src="images/kata_2_code.png" alt="kata_2_code" width="900"/>

# %%
def kata_2():
    circuit = QuantumCircuit(3)
    
    # todo: complete the circuit


    return circuit

# %%
qc_k2 = kata_2()
qc_k2.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k2)

# %% [markdown]
# # Kata 3:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_3.png" alt="kata_3" width="900"/>  |  <img src="images/kata_3_code.png" alt="kata_3_code" width="900"/>

# %%
def kata_3():
    circuit = QuantumCircuit(3)
    
    # todo: complete the circuit


    return circuit

# %%
qc_k3 = kata_3()
qc_k3.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k3)

# %% [markdown]
# # Kata 4:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/Kata_4.png" alt="kata_4" width="900"/>  |  <img src="images/kata_4_code.png" alt="kata_4_code" width="900"/>

# %%
def kata_4():
    circuit = QuantumCircuit(3)
    
    # todo: complete the circuit

    
    return circuit

# %%
qc_k4 = kata_4()
qc_k4.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k4)

# %% [markdown]
# # Kata 5:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_5.png" alt="kata_5" width="900"/>  |  <img src="images/kata_5_code.png" alt="kata_5_code" width="900"/>

# %%
import math
def kata_5():
    circuit = QuantumCircuit(2)
    
    # todo: complete the circuit


    return circuit

# %%
qc_k5 = kata_5()
qc_k5.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k5)

# %% [markdown]
# # Kata 6:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_6.png" alt="kata_6" width="900"/>  |  <img src="images/kata_6_code.png" alt="kata_6_code" width="900"/>

# %%
def kata_6():
    circuit = QuantumCircuit(2)
    
    # todo: complete the circuit

    
    return circuit

# %%
qc_k6 = kata_6()
qc_k6.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k6)

# %% [markdown]
# # Kata 7:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_7.png" alt="kata_7" width="900"/>  |  <img src="images/kata_7_code.png" alt="kata_7_code" width="900"/>

# %%
def kata_7():
    circuit = QuantumCircuit(2)
    
    # todo: complete the circuit

    return circuit

# %%
qc_k7 = kata_7()
qc_k7.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k7)

# %% [markdown]
# # Kata 8:
#
# IBM Composer             |  Visualization result
# :-------------------------:|:-------------------------:
# <img src="images/kata_8.png" alt="kata_8" width="900"/>  |  <img src="images/kata_8_code.png" alt="kata_8_code" width="900"/>

# %%
def kata_8():
    circuit = QuantumCircuit(2)
    
    # todo: complete the circuit

    
    return circuit

# %%
qc_k8 = kata_8()
qc_k8.draw('mpl', style="clifford")

# %%
plot_statevector(qc_k8)
